# %%
import pandas as pd 
df = pd.read_csv("D:/Python Programs/JupyNotebook/Lesson 3 Practice/Salaries.csv")
df
# Out:
# C:\Python310\lib\site-packages\IPython\core\interactiveshell.py:3251: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# ...

# %%
df.shape
# Out:
# (148648, 13)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['BasePay'].dtype
# Out:
# dtype('float64')

# %%
df.iloc[:,1:3]
# Out:
#              EmployeeName                                        JobTitle
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148643   Carolyn A Wilson                       Human Services Technician
# 148644     Joann Anderson                     Communications Dispatcher 2
# 148645        Leon Walker                                       Custodian
# 148646      Roy I Tillery                                       Custodian
# 148647          Joe Lopez                      Counselor, Log Cabin Ranch
#
# [148648 rows x 2 columns]

# %%
df.iloc[5:7,:]
# Out:
#    Id    EmployeeName                            JobTitle    BasePay  \
# 5   6  DAVID SULLIVAN           ASSISTANT DEPUTY CHIEF II  118602.00
# 6   7       ALSON LEE  BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
#
#    OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 5       8601.0  189082.74       NaN  316285.74         316285.74  2011    NaN
# 6      89062.9  134426.14       NaN  315981.05         315981.05  2011    NaN
#
#           Agency Status
# 5  San Francisco    NaN
# 6  San Francisco    NaN

# %%
df.iloc[100:148640,:]
# Out:
#             Id           EmployeeName                            JobTitle  \
# 100        101           KEVIN TAYLOR  BATTALION CHIEF, (FIRE DEPARTMENT)
# 101        102              ERIKA HOO         LIEUTENANT, FIRE DEPARTMENT
# 102        103        LAUIFI SEUMAALA                         FIREFIGHTER
# 103        104          EDWARD DENNIS                  TRANSIT SUPERVISOR
# 104        105          PATRIC STEELE                         FIREFIGHTER
# ...        ...                    ...                                 ...
# 148635  148638       Kadeshra D Green              Transit Fare Inspector
# 148636  148639   Lennard B Hutchinson                         Electrician
# 148637  148640      Richard A Talbert                           Custodian
# 148638  148641     Charlene D Mccully             Parking Control Officer
# 148639  148642  Raphael Marquis Goins                        Museum Guard
#
#           BasePay  OvertimePay  OtherPay  Benefits   TotalPay  \
# ...

# %%
df['TotalPay'].unique()
# Out:
# array([ 5.6759543e+05,  5.3890928e+05,  3.3527991e+05, ...,
#         1.2890000e+01,  6.0000000e+00, -6.1813000e+02])

# %%
df['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ...,
#        'Forensic Toxicologist Supervis', 'Conversion', 'Cashier 3'],
#       dtype=object)

# %%
#df['hp'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.mean()

# %%
df.median()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15184\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
df.mode(axis=0)
# Out:
#                   model   mpg  cyl   disp     hp  drat    wt   qsec   vs   am  \
# 0           AMC Javelin  10.4  8.0  275.8  110.0  3.07  3.44  17.02  0.0  0.0
# 1    Cadillac Fleetwood  15.2  NaN    NaN  175.0  3.92   NaN  18.90  NaN  NaN
# 2            Camaro Z28  19.2  NaN    NaN  180.0   NaN   NaN    NaN  NaN  NaN
# 3     Chrysler Imperial  21.0  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 4            Datsun 710  21.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 5      Dodge Challenger  22.8  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 6            Duster 360  30.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 7          Ferrari Dino   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 8              Fiat 128   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 9             Fiat X1-9   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 10       Ford Pantera L   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
correlations = df.corr()
sns.heatmap(data = correlations,square = True, cmap = "bwr") #cmap = "viridis"
plt.yticks(rotation=0)
plt.xticks(rotation=90)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  [Text(0.5, 0, 'mpg'),
#   Text(1.5, 0, 'cyl'),
#   Text(2.5, 0, 'disp'),
#   Text(3.5, 0, 'hp'),
#   Text(4.5, 0, 'drat'),
#   Text(5.5, 0, 'wt'),
#   Text(6.5, 0, 'qsec'),
#   Text(7.5, 0, 'vs'),
#   Text(8.5, 0, 'am'),
#   Text(9.5, 0, 'gear'),
#   Text(10.5, 0, 'carb')])

# %%
df.isna().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
sns.boxplot(x=df['wt']) #disp,hp ,wt
# Out:
# <AxesSubplot:xlabel='wt'>
